# %%
import fitz  # PyMuPDF
from PIL import Image
import pytesseract
import os
import re

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    doc = fitz.open(pdf_path)
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text += page.get_text()
    doc.close()
    return text

# %%
def perform_ocr(image_path):
    return pytesseract.image_to_string(Image.open(image_path))

# %%
def parse_invoice_text(text):
    invoice_data = {
        "Invoice Number": "",
        "Customer Name": "",
        "Ship To": "",
        "Date": "",
        "Ship Mode": "",
        "Balance Due": "",
        "Item": "",
        "Quantity": "",
        "Rate": "",
        "Amount": ""
    }
    
    # Extracting invoice number
    invoice_number = re.search(r'INVOICE\s*#\s*(\d+)', text)
    if invoice_number:
        invoice_data["Invoice Number"] = invoice_number.group(1)
    
    # Extracting customer name
    customer_name = re.search(r'Bill\s*To:\s*([\w\s]+)', text)
    if customer_name:
        invoice_data["Customer Name"] = customer_name.group(1)
    
    # Extracting ship to address
    ship_to = re.search(r'Ship\s*To:\s*([\w\s\,]+)', text)
    if ship_to:
        invoice_data["Ship To"] = ship_to.group(1)
    
    # Extracting date
    date = re.search(r'Date:\s*([\w\s]+)', text)
    if date:
        invoice_data["Date"] = date.group(1)
    
    # Extracting ship mode
    ship_mode = re.search(r'Ship\s*Mode:\s*([\w\s]+)', text)
    if ship_mode:
        invoice_data["Ship Mode"] = ship_mode.group(1)
    
    # Extracting balance due
    balance_due = re.search(r'Balance\s*Due:\s*\$([\d\.]+)', text)
    if balance_due:
        invoice_data["Balance Due"] = balance_due.group(1)
    
    # Extracting item details (assuming one item per invoice for simplicity)
    item_details = re.search(r'(\d+)\s+(\S.*?)(?:\s+\$\s*(\d+\.\d{2})\s+\$\s*(\d+\.\d{2}))', text)
    if item_details:
        invoice_data["Quantity"] = item_details.group(1)
        invoice_data["Item"] = item_details.group(2)
        invoice_data["Rate"] = item_details.group(3)
        invoice_data["Amount"] = item_details.group(4)
    
    return invoice_data

# %% [markdown]
# Example usage

# %%
pdf_path = 'C:\\Users\\Rishika\\Desktop\\AIDEIT\\data\\1000+ PDF_Invoice_Folder\\invoice_Aaron Bergman_36258.pdf'
extracted_text = extract_text_from_pdf(pdf_path)
print(extracted_text)
# Out:
# INVOICE
# # 36258
# SuperStore
# Bill To:
# Aaron Bergman
# Ship To:
# 98103, Seattle,
# Washington, United
# States
# Mar 06 2012
# First Class
# $50.10
# Date:
# Ship Mode:
# Balance Due:
# Item
# Quantity
# Rate
# Amount
# Global Push Button Manager's Chair, Indigo
# 1
# $48.71
# $48.71
# Chairs, Furniture, FUR-CH-4421
# $48.71
# $9.74
# $11.13
# $50.10
# Subtotal:
# Discount (20%):
# Shipping:
# Total:
# Notes:
# Thanks for your business!
# Terms:
# Order ID : CA-2012-AB10015140-40974

# %%
# Function to process all PDFs in a directory
def process_pdfs_in_directory(directory):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(directory, filename)
            extracted_text = extract_text_from_pdf(pdf_path)
            invoice_data = parse_invoice_text(extracted_text)
            data.append(invoice_data)
    return data

# %%
# Directory containing your PDF invoices
pdf_directory = r'C:\Users\Rishika\Desktop\AIDEIT\data\1000+ PDF_Invoice_Folder'

# %%
# Process PDFs and store data in a list of dictionaries
extracted_data = process_pdfs_in_directory(pdf_directory)

# %%
import pandas as pd

# %%
# Convert data to DataFrame
df = pd.DataFrame(extracted_data)

# %%
# Save DataFrame to CSV
csv_file = 'extracted_invoices.csv'
df.to_csv(csv_file, index=False)

# %%
extracted_data
# Out:
# [{'Invoice Number': '36258',
#   'Customer Name': 'Aaron Bergman\nShip To',
#   'Ship To': '98103, Seattle,\nWashington, United\nStates\nMar 06 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-4421',
#   'Quantity': '71',
#   'Rate': '48.71',
#   'Amount': '9.74'},
#  {'Invoice Number': '36259',
#   'Customer Name': 'Aaron Bergman\nShip To',
#   'Ship To': '98103, Seattle,\nWashington, United\nStates\nMar 06 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '330',
#   'Rate': '17.94',
#   'Amount': '53.82'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '39519',
#   'Customer Name': 'Aaron Bergman\nShip To',
#   'Ship To': '76017, Arlington,\nTexas, United States\nFeb 19 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Storage, Office Supplies, OFF-ST-3078',
#   'Quantity': '25',
#   'Rate': '25.25',
#   'Amount': '5.05'},
#  {'Invoice Number': '36651',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': '90004, Los Angeles,\nCalifornia, United\nStates\nMay 12 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,676.74',
#   'Quantity': '4840',
#   'Rate': '335.35',
#   'Amount': '11.69'},
#  {'Invoice Number': '36652',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': '90004, Los Angeles,\nCalifornia, United\nStates\nMay 12 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Paper, Office Supplies, OFF-PA-4014',
#   'Quantity': '00',
#   'Rate': '16.00',
#   'Amount': '1.15'},
#  {'Invoice Number': '37425',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': '94109, San\nFrancisco, California,\nUnited States\nOct 24 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4372',
#   'Quantity': '63',
#   'Rate': '197.63',
#   'Amount': '39.53'},
#  {'Invoice Number': '38460',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': '12180, Troy, New\nYork, United States\nApr 21 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '40100',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': '10035, New York City,\nNew York, United\nStates\nDec 30 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Accessories, Technology, TEC-AC-6340',
#   'Quantity': '31',
#   'Rate': '104.31',
#   'Amount': '8.22'},
#  {'Invoice Number': '40101',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': '10035, New York City,\nNew York, United\nStates\nDec 30 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '51',
#   'Rate': '18.90',
#   'Amount': '56.70'},
#  {'Invoice Number': '47905',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': 'Kamina, Katanga,\nDemocratic Republic\nof the Congo\nSep 13 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '4820',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': 'Saltillo, Coahuila,\nMexico\nDec 08 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$3,122.43',
#   'Quantity': '4861',
#   'Rate': '624.49',
#   'Amount': '226.63'},
#  {'Invoice Number': '49674',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': 'Kryvyy Rih,\nDnipropetrovs',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '6817',
#   'Customer Name': 'Aaron Hawkins\nShip To',
#   'Ship To': 'Villa Canales,\nGuatemala,\nGuatemala\nOct 23 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '15978',
#   'Customer Name': 'Aaron Smayling\nShip To',
#   'Ship To': 'Rome, Lazio, Italy\nMar 31 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35876',
#   'Customer Name': 'Aaron Smayling\nShip To',
#   'Ship To': '10035, New York City,\nNew York, United\nStates\nJul 26 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '11',
#   'Quantity': '1956',
#   'Rate': '65.78',
#   'Amount': '723.58'},
#  {'Invoice Number': '21617',
#   'Customer Name': 'Adam Bellavance\nShip To',
#   'Ship To': 'Denpasar, Bali,\nIndonesia\nMay 31 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '16384',
#   'Customer Name': 'Adam Hart\nShip To',
#   'Ship To': 'Nottingham, England,\nUnited Kingdom\nDec 08 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '30118',
#   'Customer Name': 'Adam Hart\nShip To',
#   'Ship To': 'Bunbury, Western\nAustralia, Australia\nAug 22 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$7,300.21',
#   'Quantity': '4560',
#   'Rate': '730.02',
#   'Amount': '67.18'},
#  {'Invoice Number': '30845',
#   'Customer Name': 'Adam Hart\nShip To',
#   'Ship To': 'Melton, Victoria,\nAustralia\nSep 11 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '36279',
#   'Customer Name': 'Adam Hart\nShip To',
#   'Ship To': '92646, Huntington\nBeach, California,\nUnited States\nNov 15 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Labels, Office Supplies, OFF-LA-5591',
#   'Quantity': '44',
#   'Rate': '10.44',
#   'Amount': '1.51'},
#  {'Invoice Number': '12471',
#   'Customer Name': 'Adam Shillingsburg\nShip To',
#   'Ship To': 'Breda, North Brabant,\nNetherlands\nMay 20 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '40245',
#   'Customer Name': 'Adam Shillingsburg\nShip To',
#   'Ship To': '92037, San Diego,\nCalifornia, United\nStates\nDec 23 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Appliances, Office Supplies, OFF-AP-3367',
#   'Quantity': '97',
#   'Rate': '13.97',
#   'Amount': '2.16'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '40953',
#   'Customer Name': 'Adam Shillingsburg\nShip To',
#   'Ship To': '10035, New York City,\nNew York, United\nStates\nSep 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-3729',
#   'Quantity': '98',
#   'Rate': '3.98',
#   'Amount': '0.80'},
#  {'Invoice Number': '40954',
#   'Customer Name': 'Adam Shillingsburg\nShip To',
#   'Ship To': '10035, New York City,\nNew York, United\nStates\nSep 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Art, Office Supplies, OFF-AR-3285',
#   'Quantity': '16',
#   'Rate': '52.16',
#   'Amount': '1.16'},
#  {'Invoice Number': '40955',
#   'Customer Name': 'Adam Shillingsburg\nShip To',
#   'Ship To': '10035, New York City,\nNew York, United\nStates\nSep 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$2,318.11',
#   'Quantity': '5430',
#   'Rate': '231.81',
#   'Amount': '64.56'},
#  {'Invoice Number': '25445',
#   'Customer Name': 'Adrian Barton\nShip To',
#   'Ship To': 'Kochi, Kerala, India\nDec 27 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35579',
#   'Customer Name': 'Adrian Barton\nShip To',
#   'Ship To': '46203, Indianapolis,\nIndiana, United\nStates\nDec 19 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '1',
#   'Quantity': '487',
#   'Rate': '3.69',
#   'Amount': '3.69'},
#  {'Invoice Number': '35580',
#   'Customer Name': 'Adrian Barton\nShip To',
#   'Ship To': '46203, Indianapolis,\nIndiana, United\nStates\nDec 19 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '33399',
#   'Customer Name': 'Adrian Hane\nShip To',
#   'Ship To': '85705, Tucson,\nArizona, United\nStates\nJul 17 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,036.54',
#   'Quantity': '5428',
#   'Rate': '207.31',
#   'Amount': '31.15'},
#  {'Invoice Number': '39793',
#   'Customer Name': 'Aimee Bixby\nShip To',
#   'Ship To': '10701, Yonkers, New\nYork, United States\nMar 04 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '345',
#   'Rate': '59.52',
#   'Amount': '178.56'},
#  {'Invoice Number': '39794',
#   'Customer Name': 'Aimee Bixby\nShip To',
#   'Ship To': '10701, Yonkers, New\nYork, United States\nMar 04 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '39795',
#   'Customer Name': 'Aimee Bixby\nShip To',
#   'Ship To': '10701, Yonkers, New\nYork, United States\nMar 04 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Supplies, Office Supplies, OFF-SU-2972',
#   'Quantity': '24',
#   'Rate': '37.24',
#   'Amount': '1.91'},
#  {'Invoice Number': '39796',
#   'Customer Name': 'Aimee Bixby\nShip To',
#   'Ship To': '10701, Yonkers, New\nYork, United States\nMar 04 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4378',
#   'Quantity': '79',
#   'Rate': '297.79',
#   'Amount': '59.56'},
#  {'Invoice Number': '39797',
#   'Customer Name': 'Aimee Bixby\nShip To',
#   'Ship To': '10701, Yonkers, New\nYork, United States\nMar 04 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '2',
#   'Quantity': '1891',
#   'Rate': '97.82',
#   'Amount': '195.64'},
#  {'Invoice Number': '36600',
#   'Customer Name': 'Alan Barnes\nShip To',
#   'Ship To': '62521, Decatur,\nIllinois, United States\nNov 15 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-5790',
#   'Quantity': '59',
#   'Rate': '74.59',
#   'Amount': '22.38'},
#  {'Invoice Number': '1626',
#   'Customer Name': 'Alan Dominguez\nShip To',
#   'Ship To': 'Manaus, Amazonas,\nBrazil\nAug 15 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '31421',
#   'Customer Name': 'Alan Dominguez\nShip To',
#   'Ship To': '77041, Houston,\nTexas, United States\nDec 25 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,801.67',
#   'Quantity': '4400',
#   'Rate': '540.50',
#   'Amount': '58.54'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '22343',
#   'Customer Name': 'Alan Haines\nShip To',
#   'Ship To': 'Delhi, Delhi, India\nDec 20 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-5368',
#   'Quantity': '36',
#   'Rate': '735.36',
#   'Amount': '68.59'},
#  {'Invoice Number': '29721',
#   'Customer Name': 'Alan Haines\nShip To',
#   'Ship To': 'Antipolo, Calabarzon,\nPhilippines\nNov 24 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '36551',
#   'Customer Name': 'Alan Haines\nShip To',
#   'Ship To': '18018, Bethlehem,\nPennsylvania, United\nStates\nMar 05 2013\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-6016',
#   'Quantity': '74',
#   'Rate': '198.74',
#   'Amount': '59.62'},
#  {'Invoice Number': '36552',
#   'Customer Name': 'Alan Haines\nShip To',
#   'Ship To': '18018, Bethlehem,\nPennsylvania, United\nStates\nMar 05 2013\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-2864',
#   'Quantity': '14',
#   'Rate': '67.14',
#   'Amount': '13.43'},
#  {'Invoice Number': '42998',
#   'Customer Name': 'Alan Haines\nShip To',
#   'Ship To': 'Waterloo, Ontario,\nCanada\nAug 08 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Envelopes, Office Supplies, OFF-EN-3089',
#   'Quantity': '04',
#   'Rate': '527.04',
#   'Amount': '7.97'},
#  {'Invoice Number': '5873',
#   'Customer Name': 'Alan Haines\nShip To',
#   'Ship To': 'San Salvador, San\nSalvador, El Salvador\nJan 17 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$15,527.06',
#   'Quantity': '4574',
#   'Rate': '31.05',
#   'Amount': '159.52'},
#  {'Invoice Number': '14266',
#   'Customer Name': 'Alan Hwang\nShip To',
#   'Ship To': 'Paris, Ile',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '14267',
#   'Customer Name': 'Alan Hwang\nShip To',
#   'Ship To': 'Paris, Ile',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,112.45',
#   'Quantity': '4259',
#   'Rate': '111.25',
#   'Amount': '74.42'},
#  {'Invoice Number': '14269',
#   'Customer Name': 'Alan Hwang\nShip To',
#   'Ship To': 'Paris, Ile',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,137.86',
#   'Quantity': '3599',
#   'Rate': '170.68',
#   'Amount': '81.24'},
#  {'Invoice Number': '28262',
#   'Customer Name': 'Alan Hwang\nShip To',
#   'Ship To': 'Baotou, Inner\nMongolia, China\nDec 05 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35712',
#   'Customer Name': 'Alan Hwang\nShip To',
#   'Ship To': '94122, San\nFrancisco, California,\nUnited States\nNov 28 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,151.84',
#   'Quantity': '6413',
#   'Rate': '230.37',
#   'Amount': '17.88'},
#  {'Invoice Number': '35713',
#   'Customer Name': 'Alan Hwang\nShip To',
#   'Ship To': '94122, San\nFrancisco, California,\nUnited States\nNov 28 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Fasteners, Office Supplies, OFF-FA-6129',
#   'Quantity': '00',
#   'Rate': '152.00',
#   'Amount': '2.12'},
#  {'Invoice Number': '33272',
#   'Customer Name': 'Alan Schoenberger\nShip To',
#   'Ship To': '36116, Montgomery,\nAlabama, United\nStates\nOct 17 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Storage, Office Supplies, OFF-ST-4456',
#   'Quantity': '91',
#   'Rate': '827.91',
#   'Amount': '36.12'},
#  {'Invoice Number': '33273',
#   'Customer Name': 'Alan Schoenberger\nShip To',
#   'Ship To': '36116, Montgomery,\nAlabama, United\nStates\nOct 17 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '33274',
#   'Customer Name': 'Alan Schoenberger\nShip To',
#   'Ship To': '36116, Montgomery,\nAlabama, United\nStates\nOct 17 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '31899',
#   'Customer Name': 'Alan Shonely\nShip To',
#   'Ship To': '33614, Tampa,\nFlorida, United States\nMar 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Storage, Office Supplies, OFF-ST-4752',
#   'Quantity': '78',
#   'Rate': '142.78',
#   'Amount': '28.56'},
#  {'Invoice Number': '31900',
#   'Customer Name': 'Alan Shonely\nShip To',
#   'Ship To': '33614, Tampa,\nFlorida, United States\nMar 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-4048',
#   'Quantity': '09',
#   'Rate': '137.09',
#   'Amount': '27.42'},
#  {'Invoice Number': '31901',
#   'Customer Name': 'Alan Shonely\nShip To',
#   'Ship To': '33614, Tampa,\nFlorida, United States\nMar 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4885',
#   'Quantity': '65',
#   'Rate': '21.65',
#   'Amount': '15.16'},
#  {'Invoice Number': '31902',
#   'Customer Name': 'Alan Shonely\nShip To',
#   'Ship To': '33614, Tampa,\nFlorida, United States\nMar 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4375',
#   'Quantity': '75',
#   'Rate': '172.75',
#   'Amount': '120.93'},
#  {'Invoice Number': '31903',
#   'Customer Name': 'Alan Shonely\nShip To',
#   'Ship To': '33614, Tampa,\nFlorida, United States\nMar 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '1889',
#   'Rate': '131.90',
#   'Amount': '395.71'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '43048',
#   'Customer Name': 'Alan Shonely\nShip To',
#   'Ship To': 'Vaughan, Ontario,\nCanada\nSep 20 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Labels, Office Supplies, OFF-LA-6054',
#   'Quantity': '80',
#   'Rate': '4.80',
#   'Amount': '1.35'},
#  {'Invoice Number': '40780',
#   'Customer Name': 'Alejandro Ballentine\nShip To',
#   'Ship To': '90008, Los Angeles,\nCalifornia, United\nStates\nJul 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Art, Office Supplies, OFF-AR-3853',
#   'Quantity': '08',
#   'Rate': '118.08',
#   'Amount': '1.37'},
#  {'Invoice Number': '24518',
#   'Customer Name': 'Alejandro Grove\nShip To',
#   'Ship To': 'Shantou,\nGuangdong, China\nJan 11 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '31314',
#   'Customer Name': 'Alejandro Grove\nShip To',
#   'Ship To': '84084, West Jordan,\nUtah, United States\nMay 12 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Storage, Office Supplies, OFF-ST-4290',
#   'Quantity': '00',
#   'Rate': '111.00',
#   'Amount': '1.82'},
#  {'Invoice Number': '38707',
#   'Customer Name': 'Alejandro Grove\nShip To',
#   'Ship To': '10011, New York City,\nNew York, United\nStates\nJul 22 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Accessories, Technology, TEC-AC-3748',
#   'Quantity': '96',
#   'Rate': '199.96',
#   'Amount': '22.93'},
#  {'Invoice Number': '20581',
#   'Customer Name': 'Alejandro Savely\nShip To',
#   'Ship To': 'Kanpur, Uttar\nPradesh, India\nNov 08 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Phones, Technology, TEC-PH-5351',
#   'Quantity': '16',
#   'Rate': '551.16',
#   'Amount': '83.73'},
#  {'Invoice Number': '20583',
#   'Customer Name': 'Alejandro Savely\nShip To',
#   'Ship To': 'Kanpur, Uttar\nPradesh, India\nNov 08 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '41450',
#   'Customer Name': 'Alejandro Savely\nShip To',
#   'Ship To': 'Kaliningrad,\nKaliningrad, Russia\nAug 16 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '33911',
#   'Customer Name': 'Aleksandra\nGannaway\nShip To',
#   'Ship To': '90049, Los Angeles,\nCalifornia, United\nStates\nApr 25 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-3433',
#   'Quantity': '84',
#   'Rate': '690.84',
#   'Amount': '138.17'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '33526',
#   'Customer Name': 'Alex Avila\nShip To',
#   'Ship To': '94122, San\nFrancisco, California,\nUnited States\nMar 30 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,347.14',
#   'Quantity': '4337',
#   'Rate': '269.43',
#   'Amount': '54.96'},
#  {'Invoice Number': '33527',
#   'Customer Name': 'Alex Avila\nShip To',
#   'Ship To': '94122, San\nFrancisco, California,\nUnited States\nMar 30 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Appliances, Office Supplies, OFF-AP-4242',
#   'Quantity': '96',
#   'Rate': '105.96',
#   'Amount': '3.17'},
#  {'Invoice Number': '38765',
#   'Customer Name': 'Alex Avila\nShip To',
#   'Ship To': '10011, New York City,\nNew York, United\nStates\nSep 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Fasteners, Office Supplies, OFF-FA-6129',
#   'Quantity': '82',
#   'Rate': '44.82',
#   'Amount': '1.99'},
#  {'Invoice Number': '38766',
#   'Customer Name': 'Alex Avila\nShip To',
#   'Ship To': '10011, New York City,\nNew York, United\nStates\nSep 14 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-5174',
#   'Quantity': '12',
#   'Rate': '29.12',
#   'Amount': '1.31'},
#  {'Invoice Number': '18794',
#   'Customer Name': 'Alex Grayson\nShip To',
#   'Ship To': 'Aylesbury, England,\nUnited Kingdom\nJul 19 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Storage, Office Supplies, OFF-ST-4260',
#   'Quantity': '52',
#   'Rate': '545.52',
#   'Amount': '80.24'},
#  {'Invoice Number': '28157',
#   'Customer Name': 'Alex Russell\nShip To',
#   'Ship To': 'Ho Chi Minh City, Ho\nChí Minh City,\nVietnam\nJun 09 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Bookcases, Furniture, FUR-BO-5940',
#   'Quantity': '01',
#   'Rate': '942.01',
#   'Amount': '348.54'},
#  {'Invoice Number': '38655',
#   'Customer Name': 'Alex Russell\nShip To',
#   'Ship To': '19143, Philadelphia,\nPennsylvania, United\nStates\nDec 29 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,511.78',
#   'Quantity': '3827',
#   'Rate': '604.71',
#   'Amount': '28.56'},
#  {'Invoice Number': '38656',
#   'Customer Name': 'Alex Russell\nShip To',
#   'Ship To': '19143, Philadelphia,\nPennsylvania, United\nStates\nDec 29 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,571.29',
#   'Quantity': '4622',
#   'Rate': '628.52',
#   'Amount': '28.73'},
#  {'Invoice Number': '10670',
#   'Customer Name': 'Alice McCarthy\nShip To',
#   'Ship To': 'Harrogate, England,\nUnited Kingdom\nAug 15 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '36714',
#   'Customer Name': 'Alice McCarthy\nShip To',
#   'Ship To': '68104, Omaha,\nNebraska, United\nStates\nOct 05 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4376',
#   'Quantity': '72',
#   'Rate': '30.72',
#   'Amount': '5.31'},
#  {'Invoice Number': '8673',
#   'Customer Name': 'Alice McCarthy\nShip To',
#   'Ship To': 'Choluteca,\nCholuteca, Honduras\nSep 29 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '32104',
#   'Customer Name': 'Allen Armold\nShip To',
#   'Ship To': '68104, Omaha,\nNebraska, United\nStates\nFeb 02 2013\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-3836',
#   'Quantity': '80',
#   'Rate': '56.80',
#   'Amount': '14.94'},
#  {'Invoice Number': '32105',
#   'Customer Name': 'Allen Armold\nShip To',
#   'Ship To': '68104, Omaha,\nNebraska, United\nStates\nFeb 02 2013\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Accessories, Technology, TEC-AC-4938',
#   'Quantity': '91',
#   'Rate': '449.91',
#   'Amount': '45.16'},
#  {'Invoice Number': '32469',
#   'Customer Name': 'Allen Armold\nShip To',
#   'Ship To': '90008, Los Angeles,\nCalifornia, United\nStates\nApr 20 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-2938',
#   'Quantity': '60',
#   'Rate': '82.60',
#   'Amount': '16.52'},
#  {'Invoice Number': '34304',
#   'Customer Name': 'Allen Armold\nShip To',
#   'Ship To': '91730, Rancho\nCucamonga,\nCalifornia, United\nStates\nOct 23 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-3306',
#   'Quantity': '82',
#   'Rate': '102.82',
#   'Amount': '20.56'},
#  {'Invoice Number': '36282',
#   'Customer Name': 'Allen Goldenen\nShip To',
#   'Ship To': '10009, New York City,\nNew York, United\nStates\nSep 02 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '5',
#   'Quantity': '514',
#   'Rate': '14.40',
#   'Amount': '72.00'},
#  {'Invoice Number': '39139',
#   'Customer Name': 'Allen Goldenen\nShip To',
#   'Ship To': '22204, Arlington,\nVirginia, United\nStates\nApr 18 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4344',
#   'Quantity': '15',
#   'Rate': '174.15',
#   'Amount': '8.00'},
#  {'Invoice Number': '39140',
#   'Customer Name': 'Allen Goldenen\nShip To',
#   'Ship To': '22204, Arlington,\nVirginia, United\nStates\nApr 18 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '11',
#   'Quantity': '232',
#   'Rate': '71.28',
#   'Amount': '784.08'},
#  {'Invoice Number': '27259',
#   'Customer Name': 'Allen Rosenblatt\nShip To',
#   'Ship To': 'Wuhan, Hubei, China\nJun 21 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,857.06',
#   'Quantity': '3627',
#   'Rate': '928.53',
#   'Amount': '107.12'},
#  {'Invoice Number': '33571',
#   'Customer Name': 'Allen Rosenblatt\nShip To',
#   'Ship To': '90036, Los Angeles,\nCalifornia, United\nStates\nOct 02 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Tables, Furniture, FUR-TA-3426',
#   'Quantity': '43',
#   'Rate': '143.43',
#   'Amount': '28.69'},
#  {'Invoice Number': '33572',
#   'Customer Name': 'Allen Rosenblatt\nShip To',
#   'Ship To': '90036, Los Angeles,\nCalifornia, United\nStates\nOct 02 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-4403',
#   'Quantity': '06',
#   'Rate': '367.06',
#   'Amount': '73.41'},
#  {'Invoice Number': '31634',
#   'Customer Name': 'Alyssa Crouse\nShip To',
#   'Ship To': '94122, San\nFrancisco, California,\nUnited States\nJul 11 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-6321',
#   'Quantity': '42',
#   'Rate': '15.42',
#   'Amount': '3.08'},
#  {'Invoice Number': '31635',
#   'Customer Name': 'Alyssa Crouse\nShip To',
#   'Ship To': '94122, San\nFrancisco, California,\nUnited States\nJul 11 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$2,095.06',
#   'Quantity': '4622',
#   'Rate': '419.01',
#   'Amount': '90.81'},
#  {'Invoice Number': '32473',
#   'Customer Name': 'Alyssa Tate\nShip To',
#   'Ship To': '90004, Los Angeles,\nCalifornia, United\nStates\nDec 26 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Fasteners, Office Supplies, OFF-FA-6129',
#   'Quantity': '24',
#   'Rate': '46.24',
#   'Amount': '1.06'},
#  {'Invoice Number': '41218',
#   'Customer Name': 'Alyssa Tate\nShip To',
#   'Ship To': '44312, Akron, Ohio,\nUnited States\nNov 23 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-2907',
#   'Quantity': '23',
#   'Rate': '17.23',
#   'Amount': '12.06'},
#  {'Invoice Number': '36068',
#   'Customer Name': 'Amy Cox\nShip To',
#   'Ship To': '85323, Avondale,\nArizona, United\nStates\nOct 30 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '36350',
#   'Customer Name': 'Amy Hunt\nShip To',
#   'Ship To': '75217, Dallas, Texas,\nUnited States\nJan 02 2013\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,992.00',
#   'Quantity': '4140',
#   'Rate': '398.40',
#   'Amount': '25.58'},
#  {'Invoice Number': '36351',
#   'Customer Name': 'Amy Hunt\nShip To',
#   'Ship To': '75217, Dallas, Texas,\nUnited States\nJan 02 2013\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '317',
#   'Rate': '7.06',
#   'Amount': '21.17'},
#  {'Invoice Number': '36352',
#   'Customer Name': 'Amy Hunt\nShip To',
#   'Ship To': '75217, Dallas, Texas,\nUnited States\nJan 02 2013\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '27673',
#   'Customer Name': 'Andrew Allen\nShip To',
#   'Ship To': 'Jakarta, Jakarta,\nIndonesia\nJun 23 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$4,773.33',
#   'Quantity': '5839',
#   'Rate': '811.47',
#   'Amount': '179.38'},
#  {'Invoice Number': '32756',
#   'Customer Name': 'Andrew Allen\nShip To',
#   'Ship To': '6457, Middletown,\nConnecticut, United\nStates\nMay 03 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-3924',
#   'Quantity': '92',
#   'Rate': '54.92',
#   'Amount': '6.23'},
#  {'Invoice Number': '12447',
#   'Customer Name': 'Andrew Gjertsen\nShip To',
#   'Ship To': 'Saint',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$2,029.10',
#   'Quantity': '5448',
#   'Rate': '202.91',
#   'Amount': '141.04'},
#  {'Invoice Number': '15999',
#   'Customer Name': 'Andrew Gjertsen\nShip To',
#   'Ship To': 'La Seyne',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '28750',
#   'Customer Name': 'Andrew Gjertsen\nShip To',
#   'Ship To': 'Xiangtan, Hunan,\nChina\nDec 05 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '36943',
#   'Customer Name': 'Andrew Gjertsen\nShip To',
#   'Ship To': '22304, Alexandria,\nVirginia, United\nStates\nJan 03 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '15115',
#   'Customer Name': 'Andrew Roberts\nShip To',
#   'Ship To': 'Toulon, Provence',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '21464',
#   'Customer Name': 'Andrew Roberts\nShip To',
#   'Ship To': 'Jining, Inner\nMongolia, China\nDec 23 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '31904',
#   'Customer Name': 'Andrew Roberts\nShip To',
#   'Ship To': '19134, Philadelphia,\nPennsylvania, United\nStates\nMay 22 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-3119',
#   'Quantity': '56',
#   'Rate': '6.56',
#   'Amount': '4.59'},
#  {'Invoice Number': '31905',
#   'Customer Name': 'Andrew Roberts\nShip To',
#   'Ship To': '19134, Philadelphia,\nPennsylvania, United\nStates\nMay 22 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '9',
#   'Quantity': '317',
#   'Rate': '21.17',
#   'Amount': '190.51'},
#  {'Invoice Number': '31906',
#   'Customer Name': 'Andrew Roberts\nShip To',
#   'Ship To': '19134, Philadelphia,\nPennsylvania, United\nStates\nMay 22 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '2',
#   'Quantity': '804',
#   'Rate': '55.19',
#   'Amount': '110.38'},
#  {'Invoice Number': '37121',
#   'Customer Name': 'Andrew Roberts\nShip To',
#   'Ship To': '43229, Columbus,\nOhio, United States\nMay 01 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Appliances, Office Supplies, OFF-AP-3364',
#   'Quantity': '41',
#   'Rate': '78.41',
#   'Amount': '15.68'},
#  {'Invoice Number': '31611',
#   'Customer Name': 'Andy Gerbode\nShip To',
#   'Ship To': '33710, Saint\nPetersburg, Florida,\nUnited States\nAug 08 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Phones, Technology, TEC-PH-3160',
#   'Quantity': '77',
#   'Rate': '356.77',
#   'Amount': '71.35'},
#  {'Invoice Number': '31612',
#   'Customer Name': 'Andy Gerbode\nShip To',
#   'Ship To': '33710, Saint\nPetersburg, Florida,\nUnited States\nAug 08 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '21',
#   'Rate': '15.55',
#   'Amount': '46.66'},
#  {'Invoice Number': '38585',
#   'Customer Name': 'Andy Gerbode\nShip To',
#   'Ship To': '77095, Houston,\nTexas, United States\nSep 01 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,679.13',
#   'Quantity': '4213',
#   'Rate': '671.65',
#   'Amount': '44.72'},
#  {'Invoice Number': '24876',
#   'Customer Name': 'Andy Reiter\nShip To',
#   'Ship To': 'Jodhpur, Rajasthan,\nIndia\nJan 01 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35286',
#   'Customer Name': 'Andy Reiter\nShip To',
#   'Ship To': '2895, Woonsocket,\nRhode Island, United\nStates\nNov 24 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-3909',
#   'Quantity': '92',
#   'Rate': '105.92',
#   'Amount': '2.72'},
#  {'Invoice Number': '37312',
#   'Customer Name': 'Andy Yotov\nShip To',
#   'Ship To': '90049, Los Angeles,\nCalifornia, United\nStates\nApr 05 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-6227',
#   'Quantity': '92',
#   'Rate': '183.92',
#   'Amount': '2.77'},
#  {'Invoice Number': '37313',
#   'Customer Name': 'Andy Yotov\nShip To',
#   'Ship To': '90049, Los Angeles,\nCalifornia, United\nStates\nApr 05 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-3829',
#   'Quantity': '77',
#   'Rate': '231.77',
#   'Amount': '4.35'},
#  {'Invoice Number': '37314',
#   'Customer Name': 'Andy Yotov\nShip To',
#   'Ship To': '90049, Los Angeles,\nCalifornia, United\nStates\nApr 05 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '211',
#   'Rate': '19.44',
#   'Amount': '58.32'},
#  {'Invoice Number': '37315',
#   'Customer Name': 'Andy Yotov\nShip To',
#   'Ship To': '90049, Los Angeles,\nCalifornia, United\nStates\nApr 05 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '1',
#   'Quantity': '194',
#   'Rate': '55.48',
#   'Amount': '55.48'},
#  {'Invoice Number': '39986',
#   'Customer Name': 'Andy Yotov\nShip To',
#   'Ship To': '19140, Philadelphia,\nPennsylvania, United\nStates\nDec 25 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Art, Office Supplies, OFF-AR-4099',
#   'Quantity': '05',
#   'Rate': '24.05',
#   'Amount': '4.81'},
#  {'Invoice Number': '8876',
#   'Customer Name': 'Anemone Ratner\nShip To',
#   'Ship To': 'Tegucigalpa,\nFrancisco Morazán,\nHonduras\nApr 20 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '12988',
#   'Customer Name': 'Angele Hood\nShip To',
#   'Ship To': 'Ghent, East Flanders,\nBelgium\nJun 07 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35601',
#   'Customer Name': 'Angele Hood\nShip To',
#   'Ship To': '98105, Seattle,\nWashington, United\nStates\nOct 25 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-6234',
#   'Quantity': '68',
#   'Rate': '255.68',
#   'Amount': '3.50'},
#  {'Invoice Number': '35602',
#   'Customer Name': 'Angele Hood\nShip To',
#   'Ship To': '98105, Seattle,\nWashington, United\nStates\nOct 25 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,919.80',
#   'Quantity': '6347',
#   'Rate': '383.96',
#   'Amount': '45.79'},
#  {'Invoice Number': '35427',
#   'Customer Name': 'Ann Blume\nShip To',
#   'Ship To': '60623, Chicago,\nIllinois, United States\nNov 17 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4377',
#   'Quantity': '40',
#   'Rate': '72.40',
#   'Amount': '57.92'},
#  {'Invoice Number': '35513',
#   'Customer Name': 'Ann Blume\nShip To',
#   'Ship To': '90004, Los Angeles,\nCalifornia, United\nStates\nFeb 17 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Labels, Office Supplies, OFF-LA-6022',
#   'Quantity': '72',
#   'Rate': '27.72',
#   'Amount': '1.70'},
#  {'Invoice Number': '49366',
#   'Customer Name': 'Ann Blume\nShip To',
#   'Ship To': 'Tallinn, Harjumaa,\nEstonia\nJan 24 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Appliances, Office Supplies, OFF-AP-3578',
#   'Quantity': '97',
#   'Rate': '560.97',
#   'Amount': '133.57'},
#  {'Invoice Number': '49367',
#   'Customer Name': 'Ann Blume\nShip To',
#   'Ship To': 'Tallinn, Harjumaa,\nEstonia\nJan 24 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '42692',
#   'Customer Name': 'Ann Chong\nShip To',
#   'Ship To': 'Nairobi, Nairobi,\nKenya\nSep 30 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '33707',
#   'Customer Name': 'Ann Steele\nShip To',
#   'Ship To': '19120, Philadelphia,\nPennsylvania, United\nStates\nJul 31 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Fasteners, Office Supplies, OFF-FA-2903',
#   'Quantity': '36',
#   'Rate': '11.36',
#   'Amount': '2.27'},
#  {'Invoice Number': '39387',
#   'Customer Name': 'Ann Steele\nShip To',
#   'Ship To': '98103, Seattle,\nWashington, United\nStates\nDec 06 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '51179',
#   'Customer Name': 'Ann Steele\nShip To',
#   'Ship To': 'Lagos, Lagos,\nNigeria\nJul 06 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,824.78',
#   'Quantity': '83',
#   'Rate': '164.81',
#   'Amount': '946.86'},
#  {'Invoice Number': '35317',
#   'Customer Name': 'Anna Andreadi\nShip To',
#   'Ship To': '19013, Chester,\nPennsylvania, United\nStates\nJun 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-5536',
#   'Quantity': '17',
#   'Rate': '510.17',
#   'Amount': '153.05'},
#  {'Invoice Number': '35318',
#   'Customer Name': 'Anna Andreadi\nShip To',
#   'Ship To': '19013, Chester,\nPennsylvania, United\nStates\nJun 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '3',
#   'Quantity': '550',
#   'Rate': '82.78',
#   'Amount': '248.35'},
#  {'Invoice Number': '35319',
#   'Customer Name': 'Anna Andreadi\nShip To',
#   'Ship To': '19013, Chester,\nPennsylvania, United\nStates\nJun 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '39300',
#   'Customer Name': 'Anna Andreadi\nShip To',
#   'Ship To': '1852, Lowell,\nMassachusetts,\nUnited States\nNov 30 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Phones, Technology, TEC-PH-3795',
#   'Quantity': '80',
#   'Rate': '543.80',
#   'Amount': '62.54'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '39302',
#   'Customer Name': 'Anna Andreadi\nShip To',
#   'Ship To': '1852, Lowell,\nMassachusetts,\nUnited States\nNov 30 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-6331',
#   'Quantity': '64',
#   'Rate': '19.64',
#   'Amount': '1.27'},
#  {'Invoice Number': '36194',
#   'Customer Name': 'Anna Chung\nShip To',
#   'Ship To': '44134, Parma, Ohio,\nUnited States\nOct 14 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Chairs, Furniture, FUR-CH-4413',
#   'Quantity': '74',
#   'Rate': '366.74',
#   'Amount': '110.02'},
#  {'Invoice Number': '36195',
#   'Customer Name': 'Anna Chung\nShip To',
#   'Ship To': '44134, Parma, Ohio,\nUnited States\nOct 14 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '2',
#   'Quantity': '1897',
#   'Rate': '7.97',
#   'Amount': '15.94'},
#  {'Invoice Number': '42837',
#   'Customer Name': 'Anna Gayman\nShip To',
#   'Ship To': 'Vienna, Vienna,\nAustria\nSep 01 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Tables, Furniture, FUR-TA-4646',
#   'Quantity': '95',
#   'Rate': '922.95',
#   'Amount': '282.09'},
#  {'Invoice Number': '40216',
#   'Customer Name': 'Anna Häberlin\nShip To',
#   'Ship To': '23464, Virginia\nBeach, Virginia,\nUnited States\nApr 01 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-5158',
#   'Quantity': '36',
#   'Rate': '355.36',
#   'Amount': '10.84'},
#  {'Invoice Number': '19331',
#   'Customer Name': 'Anne McFarland\nShip To',
#   'Ship To': 'Trier, Rhineland',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35500',
#   'Customer Name': 'Anne McFarland\nShip To',
#   'Ship To': '2920, Cranston,\nRhode Island, United\nStates\nOct 30 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Art, Office Supplies, OFF-AR-5156',
#   'Quantity': '25',
#   'Rate': '246.25',
#   'Amount': '2.26'},
#  {'Invoice Number': '',
#   'Customer Name': 'Jun 5',
#   'Ship To': '',
#   'Date': 'Balance Due',
#   'Ship Mode': '',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '35502',
#   'Customer Name': 'Anne McFarland\nShip To',
#   'Ship To': '2920, Cranston,\nRhode Island, United\nStates\nOct 30 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-4054',
#   'Quantity': '52',
#   'Rate': '29.52',
#   'Amount': '2.37'},
#  {'Invoice Number': '35503',
#   'Customer Name': 'Anne McFarland\nShip To',
#   'Ship To': '2920, Cranston,\nRhode Island, United\nStates\nOct 30 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Binders, Office Supplies, OFF-BI-4364',
#   'Quantity': '16',
#   'Rate': '68.16',
#   'Amount': '1.37'},
#  {'Invoice Number': '35504',
#   'Customer Name': 'Anne McFarland\nShip To',
#   'Ship To': '2920, Cranston,\nRhode Island, United\nStates\nOct 30 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Furnishings, Furniture, FUR-FU-4109',
#   'Quantity': '01',
#   'Rate': '53.01',
#   'Amount': '1.53'},
#  {'Invoice Number': '35505',
#   'Customer Name': 'Anne McFarland\nShip To',
#   'Ship To': '2920, Cranston,\nRhode Island, United\nStates\nOct 30 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
# ...
#   'Item': '$1,896.64',
#   'Quantity': '3597',
#   'Rate': '3.79',
#   'Amount': '105.27'},
#  {'Invoice Number': '22197',
#   'Customer Name': 'Theresa Coyne\nShip To',
#   'Ship To': 'Melbourne, Victoria,\nAustralia\nJan 12 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '22198',
#   'Customer Name': 'Theresa Coyne\nShip To',
#   'Ship To': 'Melbourne, Victoria,\nAustralia\nJan 12 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,281.31',
#   'Quantity': '6012',
#   'Rate': '128.13',
#   'Amount': '79.57'},
#  {'Invoice Number': '21236',
#   'Customer Name': 'Theresa Swint\nShip To',
#   'Ship To': 'Manila, National\nCapital, Philippines\nOct 25 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '10342',
#   'Customer Name': 'Thomas Boland\nShip To',
#   'Ship To': 'Taverny, Ile',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,076.41',
#   'Quantity': '3688',
#   'Rate': '161.46',
#   'Amount': '70.11'},
#  {'Invoice Number': '23122',
#   'Customer Name': 'Thomas Boland\nShip To',
#   'Ship To': 'Kendari, Sulawesi\nTenggara, Indonesia\nAug 11 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$6,406.06',
#   'Quantity': '3685',
#   'Rate': '448.42',
#   'Amount': '145.08'},
#  {'Invoice Number': '18758',
#   'Customer Name': 'Thomas Thornton\nShip To',
#   'Ship To': 'Poissy, Ile',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '28513',
#   'Customer Name': 'Tiffany House\nShip To',
#   'Ship To': 'Caloundra,\nQueensland,\nAustralia\nAug 18 2012\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,796.18',
#   'Quantity': '5253',
#   'Rate': '179.62',
#   'Amount': '113.45'},
#  {'Invoice Number': '43958',
#   'Customer Name': 'Tim Taslimi\nShip To',
#   'Ship To': 'Lublin, Lublin,\nPoland\nNov 06 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '10745',
#   'Customer Name': 'Toby Carlisle\nShip To',
#   'Ship To': 'Talence, Aquitaine',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '48962',
#   'Customer Name': 'Toby Ritter\nShip To',
#   'Ship To': 'Dar es Salaam, Dar\nEs Salaam, Tanzania\nMay 02 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '8265',
#   'Customer Name': 'Toby Ritter\nShip To',
#   'Ship To': 'José Bonifácio, São\nPaulo, Brazil\nJul 20 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Copiers, Technology, TEC-CO-5998',
#   'Quantity': '87',
#   'Rate': '785.87',
#   'Amount': '1.57'},
#  {'Invoice Number': '30570',
#   'Customer Name': 'Toby Swindell\nShip To',
#   'Ship To': 'Porirua, Wellington,\nNew Zealand\nNov 06 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '23926',
#   'Customer Name': 'Todd Boyes\nShip To',
#   'Ship To': 'Toowoomba,\nQueensland,\nAustralia\nJun 06 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$7,482.89',
#   'Quantity': '5812',
#   'Rate': '748.29',
#   'Amount': '143.58'},
#  {'Invoice Number': '11844',
#   'Customer Name': 'Todd Sumrall\nShip To',
#   'Ship To': 'Augsburg, Bavaria,\nGermany\nJun 01 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$3,757.75',
#   'Quantity': '5773',
#   'Rate': '375.78',
#   'Amount': '176.06'},
#  {'Invoice Number': '13130',
#   'Customer Name': 'Todd Sumrall\nShip To',
#   'Ship To': 'Farnborough,\nEngland, United\nKingdom\nFeb 29 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '23466',
#   'Customer Name': 'Todd Sumrall\nShip To',
#   'Ship To': 'Visakhapatnam,\nAndhra Pradesh,\nIndia\nOct 05 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '49660',
#   'Customer Name': 'Tom Ashbrook\nShip To',
#   'Ship To': 'Silivri, Istanbul,\nTurkey\nFeb 21 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '15218',
#   'Customer Name': 'Tom Boeckenhauer\nShip To',
#   'Ship To': 'Berlin, Berlin,\nGermany\nFeb 29 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$2,915.33',
#   'Quantity': '4509',
#   'Rate': '583.07',
#   'Amount': '80.67'},
#  {'Invoice Number': '9480',
#   'Customer Name': 'Tom Prescott\nShip To',
#   'Ship To': 'Sancti Spíritus,\nSancti Spíritus, Cuba\nFeb 09 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '16794',
#   'Customer Name': 'Tom Stivers\nShip To',
#   'Ship To': 'Brindisi, Apulia, Italy\nApr 17 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,899.94',
#   'Quantity': '4078',
#   'Rate': '759.98',
#   'Amount': '163.42'},
#  {'Invoice Number': '43613',
#   'Customer Name': 'Tom Stivers\nShip To',
#   'Ship To': 'Qom, Qom, Iran\nFeb 24 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Phones, Technology, TEC-PH-3807',
#   'Quantity': '24',
#   'Rate': '654.24',
#   'Amount': '136.02'},
#  {'Invoice Number': '24694',
#   'Customer Name': 'Tom Zandusky\nShip To',
#   'Ship To': 'Chongqing,\nChongqing, China\nDec 07 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '2964',
#   'Customer Name': 'Tom Zandusky\nShip To',
#   'Ship To': 'Santo Domingo,\nSanto Domingo,\nDominican Republic\nMay 17 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '2967',
#   'Customer Name': 'Tom Zandusky\nShip To',
#   'Ship To': 'Santo Domingo,\nSanto Domingo,\nDominican Republic\nMay 17 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '12100',
#   'Customer Name': 'Tonja Turnell\nShip To',
#   'Ship To': 'Nancy, Alsace',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '18457',
#   'Customer Name': 'Tonja Turnell\nShip To',
#   'Ship To': 'Pforzheim, Baden',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '26169',
#   'Customer Name': 'Tonja Turnell\nShip To',
#   'Ship To': 'Kuala Lumpur, Kuala\nLumpur, Malaysia\nJan 15 2013\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '25880',
#   'Customer Name': 'Tony Molinari\nShip To',
#   'Ship To': 'Surabaya, Jawa\nTimur, Indonesia\nNov 17 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,880.45',
#   'Quantity': '5692',
#   'Rate': '319.68',
#   'Amount': '199.05'},
#  {'Invoice Number': '25881',
#   'Customer Name': 'Tony Molinari\nShip To',
#   'Ship To': 'Surabaya, Jawa\nTimur, Indonesia\nNov 17 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '20584',
#   'Customer Name': 'Tracy Blumstein\nShip To',
#   'Ship To': 'Pekanbaru, Riau,\nIndonesia\nOct 25 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,724.18',
#   'Quantity': '3575',
#   'Rate': '293.11',
#   'Amount': '120.50'},
#  {'Invoice Number': '28215',
#   'Customer Name': 'Tracy Blumstein\nShip To',
#   'Ship To': 'Geelong, Victoria,\nAustralia\nJun 23 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$3,642.98',
#   'Quantity': '6138',
#   'Rate': '364.30',
#   'Amount': '86.38'},
#  {'Invoice Number': '21272',
#   'Customer Name': 'Tracy Hopkins\nShip To',
#   'Ship To': 'Melbourne, Victoria,\nAustralia\nJul 19 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Copiers, Technology, TEC-CO-4586',
#   'Quantity': '56',
#   'Rate': '524.56',
#   'Amount': '52.46'},
#  {'Invoice Number': '13856',
#   'Customer Name': 'Tracy Poddar\nShip To',
#   'Ship To': 'Farnborough,\nEngland, United\nKingdom\nJun 13 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '18864',
#   'Customer Name': 'Troy Blackwell\nShip To',
#   'Ship To': 'Vienna, Vienna,\nAustria\nNov 21 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '25750',
#   'Customer Name': 'Troy Staebel\nShip To',
#   'Ship To': 'Sydney, New South\nWales, Australia\nDec 07 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$4,617.97',
#   'Quantity': '3605',
#   'Rate': '461.80',
#   'Amount': '73.63'},
#  {'Invoice Number': '30584',
#   'Customer Name': 'Troy Staebel\nShip To',
#   'Ship To': 'Paraparaumu,\nWellington, New\nZealand\nJan 31 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '30585',
#   'Customer Name': 'Troy Staebel\nShip To',
#   'Ship To': 'Paraparaumu,\nWellington, New\nZealand\nJan 31 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '15209',
#   'Customer Name': 'Trudy Brown\nShip To',
#   'Ship To': 'Bayonne, Aquitaine',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$1,141.37',
#   'Quantity': '5448',
#   'Rate': '114.14',
#   'Amount': '78.32'},
#  {'Invoice Number': '15210',
#   'Customer Name': 'Trudy Brown\nShip To',
#   'Ship To': 'Bayonne, Aquitaine',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$2,821.39',
#   'Quantity': '5961',
#   'Rate': '282.14',
#   'Amount': '98.18'},
#  {'Invoice Number': '17041',
#   'Customer Name': 'Trudy Brown\nShip To',
#   'Ship To': 'Vienna, Vienna,\nAustria\nNov 23 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '17042',
#   'Customer Name': 'Trudy Brown\nShip To',
#   'Ship To': 'Vienna, Vienna,\nAustria\nNov 23 2012\nFirst Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '26186',
#   'Customer Name': 'Trudy Brown\nShip To',
#   'Ship To': 'Yangon, Yangon,\nMyanmar ',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Appliances, Office Supplies, OFF-AP-4960',
#   'Quantity': '72',
#   'Rate': '437.72',
#   'Amount': '74.41'},
#  {'Invoice Number': '21435',
#   'Customer Name': 'Trudy Glocke\nShip To',
#   'Ship To': 'Kuantan, Pahang,\nMalaysia\nJan 25 2013\nSame Day\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '14380',
#   'Customer Name': 'Trudy Schmidt\nShip To',
#   'Ship To': 'London, England,\nUnited Kingdom\nJan 10 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '19175',
#   'Customer Name': 'Valerie Dominguez\nShip To',
#   'Ship To': 'Northampton,\nEngland, United\nKingdom\nJan 19 2013\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': 'Phones, Technology, TEC-PH-5841',
#   'Quantity': '24',
#   'Rate': '636.24',
#   'Amount': '82.40'},
#  {'Invoice Number': '22655',
#   'Customer Name': 'Valerie Takahito\nShip To',
#   'Ship To': 'Handan, Hebei, China\nNov 17 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '25463',
#   'Customer Name': 'Victor Preis\nShip To',
#   'Ship To': 'Brisbane,\nQueensland,\nAustralia\nSep 14 2012\nSecond Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$5,661.12',
#   'Quantity': '4057',
#   'Rate': '566.11',
#   'Amount': '219.26'},
#  {'Invoice Number': '17080',
#   'Customer Name': 'Victoria Brennan\nShip To',
#   'Ship To': 'Paris, Ile',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$7,576.17',
#   'Quantity': '4523',
#   'Rate': '757.62',
#   'Amount': '103.97'},
#  {'Invoice Number': '30489',
#   'Customer Name': 'Victoria Wilson\nShip To',
#   'Ship To': 'Hamilton, Waikato,\nNew Zealand\nDec 15 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '20703',
#   'Customer Name': 'Vivek Grady\nShip To',
#   'Ship To': 'Surat, Gujarat, India\nAug 01 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  {'Invoice Number': '5101',
#   'Customer Name': 'Vivek Grady\nShip To',
#   'Ship To': 'León, Guanajuato,\nMexico\nJun 19 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$9,097.69',
#   'Quantity': '4591',
#   'Rate': '18.20',
#   'Amount': '84.51'},
#  {'Invoice Number': '22900',
#   'Customer Name': 'Vivek Sundaresam\nShip To',
#   'Ship To': 'Perth, Western\nAustralia, Australia\nApr 07 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$7,578.14',
#   'Quantity': '4736',
#   'Rate': '757.81',
#   'Amount': '254.37'},
#  {'Invoice Number': '22902',
#   'Customer Name': 'Vivek Sundaresam\nShip To',
#   'Ship To': 'Perth, Western\nAustralia, Australia\nApr 07 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '$9,999.94',
#   'Quantity': '4731',
#   'Rate': '999.99',
#   'Amount': '118.26'},
#  {'Invoice Number': '15577',
#   'Customer Name': 'Xylona Preis\nShip To',
#   'Ship To': 'Copenhagen,\nHovedstaden,\nDenmark\nDec 04 2012\nStandard Class\n',
#   'Date': 'Ship Mode',
#   'Ship Mode': 'Balance Due',
#   'Balance Due': '',
#   'Item': '',
#   'Quantity': '',
#   'Rate': '',
#   'Amount': ''},
#  ...]
